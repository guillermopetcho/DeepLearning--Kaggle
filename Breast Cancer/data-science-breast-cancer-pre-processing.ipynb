# %%
# importing libraries
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
# import dataset for my pc
#data = pd.read_csv ("D:/IMT/3- Data Science/3- Data pre-processing (2)/Breast_Cancer.csv")
#data

# import dataset for Kaggle
data = pd.read_csv('/kaggle/input/breast-cancer/Breast_Cancer.csv')
data
# Out:
#       Age   Race Marital Status T Stage  N Stage 6th Stage  \
# 0      68  White        Married       T1      N1       IIA
# 1      50  White        Married       T2      N2      IIIA
# 2      58  White       Divorced       T3      N3      IIIC
# 3      58  White        Married       T1      N1       IIA
# 4      47  White        Married       T2      N1       IIB
# ...   ...    ...            ...      ...     ...       ...
# 4019   62  Other        Married       T1      N1       IIA
# 4020   56  White       Divorced       T2      N2      IIIA
# 4021   68  White        Married       T2      N1       IIB
# 4022   58  Black       Divorced       T2      N1       IIB
# 4023   46  White        Married       T2      N1       IIB
#
#                   differentiate Grade   A Stage  Tumor Size Estrogen Status  \
# 0         Poorly differentiated     3  Regional           4        Positive
# 1     Moderately differentiated     2  Regional          35        Positive
# ...

# %% [markdown]
# The key challenges against it's detection is how to classify tumors into **malignant** (cancerous) or **benign** (non cancerous).
# <br>Our **target** for this dataset is to find out wether the patient is *Alive* or *Dead*, the last column, **Status**.

# %% [markdown]
# It should be checked that what was important on the result of surviving (Alive Status) or dying (Dead Status) from cancer, which of the columns were influential and should be kept in the formation of the DataFrame.<br>
# The columns that are considered should be kept in the DataFrame and the rest should not enter the DataFrame.<br>
# In this dataset, all the columns seem to be important, so they are kept in DataFrame (df) as mentioned below.

# %% [markdown]
# Here, two primary DataFrames were created. One with all the columns and the other with only a part of the columns.
#
# We will proceed with all columns for better analysis (df).
# <br>But we will also have a DataFrame and we will check that it looks at the whole case more easily (df0).

# %%
df = pd.DataFrame (data) # DataFrame with all the columns
df
# Out:
#       Age   Race Marital Status T Stage  N Stage 6th Stage  \
# 0      68  White        Married       T1      N1       IIA
# 1      50  White        Married       T2      N2      IIIA
# 2      58  White       Divorced       T3      N3      IIIC
# 3      58  White        Married       T1      N1       IIA
# 4      47  White        Married       T2      N1       IIB
# ...   ...    ...            ...      ...     ...       ...
# 4019   62  Other        Married       T1      N1       IIA
# 4020   56  White       Divorced       T2      N2      IIIA
# 4021   68  White        Married       T2      N1       IIB
# 4022   58  Black       Divorced       T2      N1       IIB
# 4023   46  White        Married       T2      N1       IIB
#
#                   differentiate Grade   A Stage  Tumor Size Estrogen Status  \
# 0         Poorly differentiated     3  Regional           4        Positive
# 1     Moderately differentiated     2  Regional          35        Positive
# ...

# %% [markdown]
# But if we want to look at the dataset more simply, we can keep only these columns.

# %%
# DataFrame with some of the columns ("Status" is *y* or *target*)
df0 = pd.DataFrame (data, columns=["Age", "Race", "Marital Status", "differentiate", "Survival Months", "Status"])
df0
# Out:
#       Age   Race Marital Status              differentiate  Survival Months  \
# 0      68  White        Married      Poorly differentiated               60
# 1      50  White        Married  Moderately differentiated               62
# 2      58  White       Divorced  Moderately differentiated               75
# 3      58  White        Married      Poorly differentiated               84
# 4      47  White        Married      Poorly differentiated               50
# ...   ...    ...            ...                        ...              ...
# 4019   62  Other        Married  Moderately differentiated               49
# 4020   56  White       Divorced  Moderately differentiated               69
# 4021   68  White        Married  Moderately differentiated               69
# 4022   58  Black       Divorced  Moderately differentiated               72
# 4023   46  White        Married  Moderately differentiated              100
#
#      Status
# 0     Alive
# 1     Alive
# 2     Alive
# ...

# %%
df.describe() # describe in the numeric way of the numeric columns
# Out:
#                Age   Tumor Size  Regional Node Examined  \
# count  4024.000000  4024.000000             4024.000000
# mean     53.972167    30.473658               14.357107
# std       8.963134    21.119696                8.099675
# min      30.000000     1.000000                1.000000
# 25%      47.000000    16.000000                9.000000
# 50%      54.000000    25.000000               14.000000
# 75%      61.000000    38.000000               19.000000
# max      69.000000   140.000000               61.000000
#
#        Reginol Node Positive  Survival Months
# count            4024.000000      4024.000000
# mean                4.158052        71.297962
# std                 5.109331        22.921430
# min                 1.000000         1.000000
# 25%                 1.000000        56.000000
# 50%                 2.000000        73.000000
# 75%                 5.000000        90.000000
# max                46.000000       107.000000

# %% [markdown]
# As you can see, there is no **Missing Value** in the *non-alphabetic* columns of the DataFrame!<br>
# Mean *Age*, *Tumor Size*, and *Survival Months* are so..<br>
# and the 'min' and 'max' are so..

# %% [markdown]
# And the rest of the non-numeric columns are described as follows;

# %%
df.describe(include=object) # describe in the alphabetic way of the verbal columns
# Out:
#          Race Marital Status T Stage  N Stage 6th Stage  \
# count    4024           4024     4024    4024      4024
# unique      3              5        4       3         5
# top     White        Married       T2      N1       IIA
# freq     3413           2643     1786    2732      1305
#
#                     differentiate Grade   A Stage Estrogen Status  \
# count                        4024  4024      4024            4024
# unique                          4     4         2               2
# top     Moderately differentiated     2  Regional        Positive
# freq                         2351  2351      3932            3755
#
#        Progesterone Status Status
# count                 4024   4024
# unique                   2      2
# top               Positive  Alive
# freq                  3326   3408

# %% [markdown]
# As you can see, there is also no **Missing Value**!<br>
# Description of this table is..

# %% [markdown]
# **Also, another thing that could be done was that if we saw that some of the columns of the dataset were not describe(), we would create a separate and NEW DataFrame with those columns completely SEPARATELY, then we would describe this newly created one.<br>
# In this way, the columns that were not included in normal describe were described.**

# %%
df.mean(numeric_only=True) # np.mean(df) : this command has warnings
# Out:
# Age                       53.972167
# Tumor Size                30.473658
# Regional Node Examined    14.357107
# Reginol Node Positive      4.158052
# Survival Months           71.297962
# dtype: float64

# %% [markdown]
# We can also calculate this but it's not that usefull. So, not important to be considered!

# %%
df.var(numeric_only=True) # np.var(df) : this command has warnings
# Out:
# Age                        80.337778
# Tumor Size                446.041563
# Regional Node Examined     65.604732
# Reginol Node Positive      26.105265
# Survival Months           525.391932
# dtype: float64

# %% [markdown]
# We can also calculate this, too. But it's not that usefull again. So, not important to be considered!

# %%
df.shape # (rows, columns)
# Out:
# (4024, 16)

# %% [markdown]
# If we want to take two columns as an example and compare them, we can:

# %%
df1 = pd.DataFrame (data, columns=["Marital Status", "Status"])
df1
# Out:
#      Marital Status Status
# 0           Married  Alive
# 1           Married  Alive
# 2          Divorced  Alive
# 3           Married  Alive
# 4           Married  Alive
# ...             ...    ...
# 4019        Married  Alive
# 4020       Divorced  Alive
# 4021        Married  Alive
# 4022       Divorced  Alive
# 4023        Married  Alive
#
# [4024 rows x 2 columns]

# %%
df2 = pd.DataFrame (data, columns=["Age", "Status"])
df2
# Out:
#       Age Status
# 0      68  Alive
# 1      50  Alive
# 2      58  Alive
# 3      58  Alive
# 4      47  Alive
# ...   ...    ...
# 4019   62  Alive
# 4020   56  Alive
# 4021   68  Alive
# 4022   58  Alive
# 4023   46  Alive
#
# [4024 rows x 2 columns]

# %%
df3 = pd.DataFrame (data, columns=["Race", "Tumor Size"])
df3
# Out:
#        Race  Tumor Size
# 0     White           4
# 1     White          35
# 2     White          63
# 3     White          18
# 4     White          41
# ...     ...         ...
# 4019  Other           9
# 4020  White          46
# 4021  White          22
# 4022  Black          44
# 4023  White          30
#
# [4024 rows x 2 columns]

# %% [markdown]
# ***
# ***
# ***

# %% [markdown]
# If we had any Missing Value problem and the x and y axis values were not equal to draw the plot, we should use the following command.<br>
# But here, since we didn't have any Missing Value, there was no need to use it.

# %%
df_new = df.dropna()
df_new
# Out:
#       Age   Race Marital Status T Stage  N Stage 6th Stage  \
# 0      68  White        Married       T1      N1       IIA
# 1      50  White        Married       T2      N2      IIIA
# 2      58  White       Divorced       T3      N3      IIIC
# 3      58  White        Married       T1      N1       IIA
# 4      47  White        Married       T2      N1       IIB
# ...   ...    ...            ...      ...     ...       ...
# 4019   62  Other        Married       T1      N1       IIA
# 4020   56  White       Divorced       T2      N2      IIIA
# 4021   68  White        Married       T2      N1       IIB
# 4022   58  Black       Divorced       T2      N1       IIB
# 4023   46  White        Married       T2      N1       IIB
#
#                   differentiate Grade   A Stage  Tumor Size Estrogen Status  \
# 0         Poorly differentiated     3  Regional           4        Positive
# 1     Moderately differentiated     2  Regional          35        Positive
# ...

# %% [markdown]
# Now we want to use plots to plot this dataset.

# %%
plt.figure(figsize=(10, 6), dpi=80) # Maximize the plot

plt.scatter(df_new['Age'], df_new['Tumor Size'], s=50, c='rebeccapurple', alpha=0.5, marker=r'$\clubsuit$', label='luck')

plt.legend (['Age'], loc = 'best')
plt.title ("Breast Cancer", fontsize=20)

plt.xlabel('Age', fontsize=15)
#plt.xticks(rotation=90) # Rotating the x labels 
plt.ylabel('Tumor Size', fontsize=15)

plt.grid()

#plt.savefig ('D:/IMT/3- Data Science/3- Data pre-processing (2)/1-Age&Tumor_Size.png')

plt.show()

# %%
plt.figure(figsize=(10, 6), dpi=80) # Maximize the plot

plt.scatter(df_new['Tumor Size'], df_new['Status'], s=30, c='rebeccapurple', alpha=0.5, marker=r'$\clubsuit$', label='luck')

plt.legend (['Tumor Size'], loc = 'best')
plt.title ("Breast Cancer", fontsize=20)

plt.xlabel('Tumor Size', fontsize=15)
#plt.xticks(rotation=90) # Rotating the x labels
plt.ylabel('Status', fontsize=15)

#plt.savefig ('D:/IMT/3- Data Science/3- Data pre-processing (2)/2-Tumor_Size&Status.png')

#plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 6), dpi=80) # Maximize the plot

plt.scatter(df_new['6th Stage'], df_new['N Stage'], s=200, c='rebeccapurple', alpha=0.5, marker=r'$\clubsuit$', label='luck')

plt.legend (['6th Stage'], loc = 'best')
plt.title ("Breast Cancer", fontsize=20)

plt.xlabel('6th Stage', fontsize=15)
#plt.xticks(rotation=90) # Rotating the x labels
plt.ylabel('N Stage', fontsize=15)

#plt.savefig ('D:/IMT/3- Data Science/3- Data pre-processing (2)/3-6th_Stage&N_Stage.png')

#plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 6), dpi=80) # Maximize the plot

plt.scatter(df_new['Survival Months'], df_new['Marital Status'], s=10, c='rebeccapurple', alpha=0.5, marker=r'$\clubsuit$', label='luck')

plt.legend (['Survival Months'], loc='upper center', bbox_to_anchor=(0.5, 1.05), ncol=3, fancybox=True, shadow=True)

plt.title ("Breast Cancer", fontsize=53)

plt.xlabel('Survival Months', fontsize=15)
#plt.xticks(rotation=90) # Rotating the x labels
plt.ylabel('Marital Status', fontsize=15)

#plt.savefig ('D:/IMT/3- Data Science/3- Data pre-processing (2)/4-Survival_Months&Marital_Status.png')


#plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 6), dpi=80) # Maximize the plot

plt.scatter(df_new['Regional Node Examined'], df_new['Reginol Node Positive'], s=30, c='rebeccapurple', alpha=0.5, marker=r'$\clubsuit$', label='luck')

plt.legend (['Regional Node Examined'], loc = 'best')
plt.title ("Breast Cancer", fontsize=20)

plt.xlabel('Regional Node Examined', fontsize=15)
#plt.xticks(rotation=90) # Rotating the x labels
plt.ylabel('Reginol Node Positive', fontsize=15)

#plt.savefig ('D:/IMT/3- Data Science/3- Data pre-processing (2)/5-Regional_Node_Examined&Reginol_Node_Positive.png')

#plt.grid()
plt.show()

# %% [markdown]
# As we saw, none of the values needed to be sorted and all the numbers were in order on both axes, but if they needed to be sorted, we could use this command:

# %% [markdown]
# df_newer = df_new.sort_values(by=['Regional Node Examined'])

# %% [markdown]
# Well, we can also use the plot bar:
# <br>We will try on these five graphs that were drawn.

# %%
plt.figure(figsize=(10, 6), dpi=80) # Maximize the plot

plt.bar(df_new['Age'], df_new['Tumor Size'], width=0.5, color="green", edgecolor="darkgreen", alpha=0.5)

plt.legend (['Age'], loc = 'best')
plt.title ("Breast Cancer", fontsize=20)

plt.xlabel('Age', fontsize=15)
#plt.xticks(rotation=90) # Rotating the x labels
plt.ylabel('Tumor Size', fontsize=15)

#plt.savefig ('D:/IMT/3- Data Science/3- Data pre-processing (2)/1-Age&Tumor_Size(bar).png')

#plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 6), dpi=80) # Maximize the plot

plt.bar(df_new['Tumor Size'], df_new['Status'], width=0.5, color="green", edgecolor="darkgreen", alpha=0.5)

plt.legend (['Tumor Size'], loc = 'best')
plt.title ("Breast Cancer", fontsize=20)

plt.xlabel('Tumor Size', fontsize=15)
#plt.xticks(rotation=90) # Rotating the x labels
plt.ylabel('Status', fontsize=15)

#plt.savefig ('D:/IMT/3- Data Science/3- Data pre-processing (2)/2-Tumor_Size&Status(bar).png')

#plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 6), dpi=80) # Maximize the plot

plt.bar(df_new['6th Stage'], df_new['N Stage'], width=0.5, color="green", edgecolor="darkgreen", alpha=0.5)

plt.legend (['6th Stage'], loc = 'best')
plt.title ("Breast Cancer", fontsize=20)

plt.xlabel('6th Stage', fontsize=15)
#plt.xticks(rotation=90) # Rotating the x labels
plt.ylabel('N Stage', fontsize=15)

#plt.savefig ('D:/IMT/3- Data Science/3- Data pre-processing (2)/3-6th_Stage&N_Stage(bar).png')

#plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 6), dpi=80) # Maximize the plot

plt.bar(df_new['Survival Months'], df_new['Marital Status'], width=0.5, color="green", edgecolor="darkgreen", alpha=0.5)

plt.legend (['Survival Months'], loc = 'best')
plt.title ("Breast Cancer", fontsize=20)

plt.xlabel('Survival Months', fontsize=15)
#plt.xticks(rotation=90) # Rotating the x labels
plt.ylabel('Marital Status', fontsize=15)

#plt.savefig ('D:/IMT/3- Data Science/3- Data pre-processing (2)/4-Survival_Months&Marital_Status(bar).png')

#plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 6), dpi=80) # Maximize the plot

plt.bar(df_new['Regional Node Examined'], df_new['Reginol Node Positive'], width=0.5, color="green", edgecolor="darkgreen", alpha=0.5)

plt.legend (['Regional Node Examined'], loc = 'best')
plt.title ("Breast Cancer", fontsize=20)

plt.xlabel('Regional Node Examined', fontsize=15)
#plt.xticks(rotation=90) # Rotating the x labels
plt.ylabel('Reginol Node Positive', fontsize=15)

#plt.savefig ('D:/IMT/3- Data Science/3- Data pre-processing (2)/5-Regional_Node_Examined&Reginol_Node_Positive(bar).png')

#plt.grid()
plt.show()

# %% [markdown]
# ***
# ***
# ***

# %% [markdown]
# We can also overlap two plots!

# %%
plt.figure(figsize=(10, 6), dpi=80) # Maximize the plot

plt.scatter(df_new['Regional Node Examined'], df_new['Status'], s=60, c='gold')
plt.scatter(df_new['Reginol Node Positive'], df_new['Status'], s=20, c='indigo')

plt.legend (['Regional Node Examined', 'Reginol Node Positive'], loc = 'best')
plt.title ("Breast Cancer", fontsize=20)

plt.xlabel('Regional / Reginols Node', fontsize=15)
#plt.xticks(rotation=90) # Rotating the x labels
plt.ylabel('Status', fontsize=15)

#plt.savefig ('D:/IMT/3- Data Science/3- Data pre-processing (2)/6-Regional_OR_Reginols_Node&Status.png')

#plt.grid()
plt.show()

# %% [markdown]
# Histogram can also get plotted:

# %%
plt.figure(figsize=(10, 6), dpi=80) # Maximize the plot

plt.hist(df_new['Age'], 
         bins=35, 
         #range=None, 
         #density=False, 
         #weights=None, 
         #cumulative=False, 
         #bottom=None, 
         histtype='stepfilled', 
         align='mid', 
         orientation='vertical', 
         #rwidth=None, 
         #log=False, 
         color='navy', 
         #label=None, 
         #stacked=False, 
         #data=None
        )

plt.legend (['Age'], loc = 'best')
plt.title ("Breast Cancer", fontsize=20)

plt.xlabel('Age', fontsize=15)
#plt.xticks(rotation=90) # Rotating the x labels

#plt.savefig ('D:/IMT/3- Data Science/3- Data pre-processing (2)/7-Age_hist.png')

#plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 6), dpi=80) # Maximize the plot

plt.hist(df_new['Race'], bins=35, histtype='stepfilled', align='mid', orientation='vertical', color='navy')

plt.legend (['Race'], loc = 'best')
plt.title ("Breast Cancer", fontsize=20)

plt.xlabel('Race', fontsize=15)
#plt.xticks(rotation=90) # Rotating the x labels

#plt.savefig ('D:/IMT/3- Data Science/3- Data pre-processing (2)/8-Race_hist.png')

#plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 6), dpi=80) # Maximize the plot

plt.hist(df_new['Marital Status'], bins=35, histtype='stepfilled', align='mid', orientation='vertical', color='navy')

plt.legend (['Marital Status'], loc = 'best')
plt.title ("Breast Cancer", fontsize=20)

plt.xlabel('Marital Status', fontsize=15)
#plt.xticks(rotation=90) # Rotating the x labels

#plt.savefig ('D:/IMT/3- Data Science/3- Data pre-processing (2)/9-Marital_Status_hist.png')

#plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 6), dpi=80) # Maximize the plot

plt.hist(df_new['N Stage'], bins=35, histtype='stepfilled', align='mid', orientation='vertical', color='navy')

plt.legend (['N Stage'], loc = 'best')
plt.title ("Breast Cancer", fontsize=20)

plt.xlabel('N Stage', fontsize=15)
#plt.xticks(rotation=90) # Rotating the x labels

#plt.savefig ('D:/IMT/3- Data Science/3- Data pre-processing (2)/10-N_Stage_hist.png')

#plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 6), dpi=80) # Maximize the plot

plt.hist(df_new['6th Stage'], bins=35, histtype='stepfilled', align='mid', orientation='vertical', color='navy')

plt.legend (['6th Stage'], loc = 'best')
plt.title ("Breast Cancer", fontsize=20)

plt.xlabel('6th Stage', fontsize=15)
#plt.xticks(rotation=90) # Rotating the x labels

#plt.savefig ('D:/IMT/3- Data Science/3- Data pre-processing (2)/11-6th_Stage_hist.png')

#plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 6), dpi=80) # Maximize the plot

plt.hist(df_new['differentiate'], bins=35, histtype='stepfilled', align='mid', orientation='vertical', color='navy')

plt.legend (['differentiate'], loc = 'best')
plt.title ("Breast Cancer", fontsize=20)

plt.xlabel('differentiate', fontsize=15)
#plt.xticks(rotation=90) # Rotating the x labels

#plt.savefig ('D:/IMT/3- Data Science/3- Data pre-processing (2)/12-differentiate_hist.png')

#plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 6), dpi=80) # Maximize the plot

plt.hist(df_new['Grade'], bins=35, histtype='stepfilled', align='mid', orientation='vertical', color='navy')

plt.legend (['Grade'], loc = 'best')
plt.title ("Breast Cancer", fontsize=20)

plt.xlabel('Grade', fontsize=15)
#plt.xticks(rotation=90) # Rotating the x labels

#plt.savefig ('D:/IMT/3- Data Science/3- Data pre-processing (2)/13-Grade_hist.png')

#plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 6), dpi=80) # Maximize the plot

plt.hist(df_new['A Stage'], bins=35, histtype='stepfilled', align='mid', orientation='vertical', color='navy')

plt.legend (['A Stage'], loc = 'best')
plt.title ("Breast Cancer", fontsize=20)

plt.xlabel('A Stage', fontsize=15)
#plt.xticks(rotation=90) # Rotating the x labels

#plt.savefig ('D:/IMT/3- Data Science/3- Data pre-processing (2)/14-A_Stage_hist.png')

#plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 6), dpi=80) # Maximize the plot

plt.hist(df_new['Tumor Size'], bins=35, histtype='stepfilled', align='mid', orientation='vertical', color='navy')

plt.legend (['Tumor Size'], loc = 'best')
plt.title ("Breast Cancer", fontsize=20)

plt.xlabel('Tumor Size', fontsize=15)
#plt.xticks(rotation=90) # Rotating the x labels

#plt.savefig ('D:/IMT/3- Data Science/3- Data pre-processing (2)/15-Tumor_Size_hist.png')

#plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 6), dpi=80) # Maximize the plot

plt.hist(df_new['Estrogen Status'], bins=35, histtype='stepfilled', align='mid', orientation='vertical', color='navy')

plt.legend (['Estrogen Status'], loc = 'best')
plt.title ("Breast Cancer", fontsize=20)

plt.xlabel('Estrogen Status', fontsize=15)
#plt.xticks(rotation=90) # Rotating the x labels

#plt.savefig ('D:/IMT/3- Data Science/3- Data pre-processing (2)/16-Estrogen_Status_hist.png')

#plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 6), dpi=80) # Maximize the plot

plt.hist(df_new['Progesterone Status'], bins=35, histtype='stepfilled', align='mid', orientation='vertical', color='navy')

plt.legend (['Progesterone Status'], loc = 'best')
plt.title ("Breast Cancer", fontsize=20)

plt.xlabel('Progesterone Status', fontsize=15)
#plt.xticks(rotation=90) # Rotating the x labels

#plt.savefig ('D:/IMT/3- Data Science/3- Data pre-processing (2)/17-Progesterone_Status_hist.png')

#plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 6), dpi=80) # Maximize the plot

plt.hist(df_new['Regional Node Examined'], bins=35, histtype='stepfilled', align='mid', orientation='vertical', color='navy')

plt.legend (['Regional Node Examined'], loc = 'best')
plt.title ("Breast Cancer", fontsize=20)

plt.xlabel('Regional Node Examined', fontsize=15)
#plt.xticks(rotation=90) # Rotating the x labels

#plt.savefig ('D:/IMT/3- Data Science/3- Data pre-processing (2)/18-Regional_Node_Examined_hist.png')

#plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 6), dpi=80) # Maximize the plot

plt.hist(df_new['Reginol Node Positive'], bins=35, histtype='stepfilled', align='mid', orientation='vertical', color='navy')

plt.legend (['Reginol Node Positive'], loc = 'best')
plt.title ("Breast Cancer", fontsize=20)

plt.xlabel('Reginol Node Positive', fontsize=15)
#plt.xticks(rotation=90) # Rotating the x labels

#plt.savefig ('D:/IMT/3- Data Science/3- Data pre-processing (2)/19-Reginol_Node_Positive_hist.png')

#plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 6), dpi=80) # Maximize the plot

plt.hist(df_new['Survival Months'], bins=35, histtype='stepfilled', align='mid', orientation='vertical', color='navy')

plt.legend (['Survival Months'], loc = 'best')
plt.title ("Breast Cancer", fontsize=20)

plt.xlabel('Survival Months', fontsize=15)
#plt.xticks(rotation=90) # Rotating the x labels

#plt.savefig ('D:/IMT/3- Data Science/3- Data pre-processing (2)/20-Survival_Months_hist.png')

#plt.grid()
plt.show()

# %%
plt.figure(figsize=(10, 6), dpi=80) # Maximize the plot

plt.hist(df_new['Status'], bins=35, histtype='stepfilled', align='mid', orientation='vertical', color='navy')

plt.legend (['Status'], loc = 'best')
plt.title ("Breast Cancer", fontsize=20)

plt.xlabel('Status', fontsize=15)
#plt.xticks(rotation=90) # Rotating the x labels

#plt.savefig ('D:/IMT/3- Data Science/3- Data pre-processing (2)/21-Status_hist.png')

#plt.grid()
plt.show()

# %% [markdown]
# End of the excercise!
