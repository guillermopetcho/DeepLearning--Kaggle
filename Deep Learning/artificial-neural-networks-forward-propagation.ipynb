# %% [markdown]
# # Artificial Neural Networks - Forward Propagation

# %% [markdown]
# ## Introduction

# %% [markdown]
# En este laboratorio, construiremos una red neuronal desde cero y programaremos su funcionamiento para realizar predicciones mediante propagación hacia adelante. Cabe mencionar que todas las bibliotecas de aprendizaje profundo ya implementan los procesos completos de entrenamiento y predicción, por lo que, en la práctica, no será necesario construir una red neuronal desde cero. Sin embargo, completar este laboratorio le ayudará a comprender mejor las redes neuronales y su funcionamiento.

# %% [markdown]
# ## Objetivo de este cuaderno * Construir una red neuronal
# * Calcular la suma ponderada en cada nodo
# * Calcular la activación de cada nodo
# * Utilizar la propagación hacia adelante para propagar los datos

# %% [markdown]
# # Resumen

# %% [markdown]
# A partir de los vídeos, recapitulemos cómo una red neuronal realiza predicciones mediante el proceso de propagación hacia adelante. Aquí tenemos una red neuronal que recibe dos entradas, tiene una capa oculta con dos nodos y una capa de salida con un nodo.

# %% [markdown]
# <img src="http://cocl.us/neural_network_example" alt="Neural Network Example" width="600px">

# %% [markdown]
# Comencemos inicializando aleatoriamente los pesos y los sesgos de la red. Tenemos 6 pesos y 3 sesgos, uno para cada nodo de la capa oculta y otro para cada nodo de la capa de salida.

# %%
import numpy as np # import Numpy library to generate 

weights = np.around(np.random.uniform(size=6), decimals=2) # initialize the weights
biases = np.around(np.random.uniform(size=3), decimals=2) # initialize the biases

# %% [markdown]
# Let's print the weights and biases for sanity check.

# %%
print(weights)
print(biases)
# Out:
# [0.97 0.38 0.81 0.77 0.1  0.74]
# [0.13 0.94 0.19]

# %% [markdown]
# Now that we have the weights and the biases defined for the network, let's compute the output for a given input, $x_1$ and $x_2$.

# %%
x_1 = 0.5 # input 1
x_2 = 0.85 # input 2

print('x1 is {} and x2 is {}'.format(x_1, x_2))
# Out:
# x1 is 0.5 and x2 is 0.85

# %% [markdown]
# Let's start by computing the weighted sum of the inputs, $z_{1, 1}$, at the first node of the hidden layer.

# %%
z_11 = x_1 * weights[0] + x_2 * weights[1] + biases[0]

print('The weighted sum of the inputs at the first node in the hidden layer is {}'.format(z_11))
# Out:
# The weighted sum of the inputs at the first node in the hidden layer is 0.9380000000000001

# %% [markdown]
# Next, let's compute the weighted sum of the inputs, $z_{1, 2}$, at the second node of the hidden layer. Assign the value to **z_12**.

# %%
### type your answer here
z_12 = x_1 * weights[2] + x_2 * weights[3] + biases[1]

# %% [markdown]
# Print the weighted sum.

# %%
print('La suma ponderada de las entradas en el segundo nodo de la capa oculta es {}'.format(np.around(z_12, decimals=4)))
# Out:
# The weighted sum of the inputs at the second node in the hidden layer is 1.9995

# %% [markdown]
# A continuación, asumiendo una función de activación sigmoide, calculemos la activación del primer nodo, $a_{1, 1}$, en la capa oculta.

# %%
a_11 = 1.0 / (1.0 + np.exp(-z_11))

print('La activación del primer nodo en la capa oculta es {}'.format(np.around(a_11, decimals=4)))
# Out:
# The activation of the first node in the hidden layer is 0.7187

# %% [markdown]
# Let's also compute the activation of the second node, $a_{1, 2}$, in the hidden layer. Assign the value to **a_12**.

# %%
### type your answer here
a_12 = 1.0 / (1.0 + np.exp(-z_12))

# %% [markdown]
# Print the activation of the second node.

# %%
print('La activación del segundo nodo en la capa oculta es {}'.format(np.around(a_12, decimals=4)))
# Out:
# The activation of the second node in the hidden layer is 0.8807

# %% [markdown]
# Now these activations will serve as the inputs to the output layer. So, let's compute the weighted sum of these inputs to the node in the output layer. Assign the value to **z_2**.

# %%
### type your answer here

z_2 = a_11 * weights[4] + a_12 * weights[5] + biases[2]

# %% [markdown]
# Print the weighted sum of the inputs at the node in the output layer.

# %%
print('La suma ponderada de las entradas en el nodo de la capa de salida es {}'.format(np.around(z_2, decimals=4)))
# Out:
# The weighted sum of the inputs at the node in the output layer is 0.9136

# %% [markdown]
# Finalmente, calculemos la salida de la red como la activación del nodo en la capa de salida. Asignemos el valor a **a_2**.

# %%
### type your answer here

a_2 = 1.0 / (1.0 + np.exp(-z_2))

# %% [markdown]
# Imprime la activación del nodo en la capa de salida que es equivalente a la predicción realizada por la red.

# %%
print('La salida de la red para x1 = 0.5 y x2 = 0.85 es {}'.format(np.around(a_2, decimals=4)))
# Out:
# The output of the network for x1 = 0.5 and x2 = 0.85 is 0.7137

# %% [markdown]
# <hr>

# %% [markdown]
# Obviamente, las redes neuronales para problemas reales se componen de muchas capas ocultas y muchos más nodos en cada capa. Por lo tanto, no podemos seguir haciendo predicciones utilizando este enfoque tan ineficiente de calcular manualmente la suma ponderada en cada nodo y la activación de cada nodo.

# %% [markdown]
# Para programar un método automático de predicción, generalicemos nuestra red. Una red general tomaría $n$ entradas, tendría varias capas ocultas, cada una con $m$ nodos, y una capa de salida. Aunque la red muestra una sola capa oculta, la programaremos para que tenga varias. De igual forma, aunque la red muestra una capa de salida con un solo nodo, la programaremos para que tenga más de un nodo en dicha capa.

# %% [markdown]
# <img src="http://cocl.us/general_neural_network" alt="Neural Network General" width="600px">

# %% [markdown]
# <a id='item12'></a>

# %% [markdown]
# ## Build a Neural Network

# %% [markdown]
# Let's start by formally defining the structure of the network.

# %%
n = 2 # number of inputs
num_hidden_layers = 2 # number of hidden layers
m = [2, 2] # number of nodes in each hidden layer
num_nodes_output = 1 # number of nodes in the output layer

# %% [markdown]
# Ahora que hemos definido la estructura de la red, procedamos a inicializar los pesos y los sesgos con números aleatorios. Para ello, necesitaremos importar la biblioteca **NumPy**.

# %%
import numpy as np # import the Numpy library

num_nodes_previous = n # number of nodes in the previous layer

network = {} # initialize network an an empty dictionary

# loop through each layer and randomly initialize the weights and biases associated with each node
# notice how we are adding 1 to the number of hidden layers in order to include the output layer
for layer in range(num_hidden_layers + 1): 
    
    # determine name of layer
    if layer == num_hidden_layers:
        layer_name = 'output'
        num_nodes = num_nodes_output
    else:
        layer_name = 'layer_{}'.format(layer + 1)
        num_nodes = m[layer]
    
    # initialize weights and biases associated with each node in the current layer
    network[layer_name] = {}
    for node in range(num_nodes):
        node_name = 'node_{}'.format(node+1)
        network[layer_name][node_name] = {
            'weights': np.around(np.random.uniform(size=num_nodes_previous), decimals=2),
            'bias': np.around(np.random.uniform(size=1), decimals=2),
        }
    
    num_nodes_previous = num_nodes
    
print(network) # print network
# Out:
# {'layer_1': {'node_1': {'weights': array([0.45, 0.87]), 'bias': array([0.49])}, 'node_2': {'weights': array([0.35, 0.66]), 'bias': array([0.32])}}, 'layer_2': {'node_1': {'weights': array([0.78, 0.62]), 'bias': array([0.96])}, 'node_2': {'weights': array([0.96, 0.86]), 'bias': array([0.72])}}, 'output': {'node_1': {'weights': array([0.63, 0.88]), 'bias': array([0.97])}}}

# %% [markdown]
# ¡Genial! Con el código anterior, podemos inicializar los pesos y los sesgos de cualquier red, independientemente del número de capas ocultas y de nodos por capa. Ahora, vamos a encapsular este código en una función para poder ejecutarlo repetidamente cada vez que queramos construir una red neuronal.

# %%
def initialize_network(num_inputs, num_hidden_layers, num_nodes_hidden, num_nodes_output):
    
    num_nodes_previous = num_inputs # number of nodes in the previous layer

    network = {}
    
    # loop through each layer and randomly initialize the weights and biases associated with each layer
    for layer in range(num_hidden_layers + 1):
        
        if layer == num_hidden_layers:
            layer_name = 'output' # name last layer in the network output
            num_nodes = num_nodes_output
        else:
            layer_name = 'layer_{}'.format(layer + 1) # otherwise give the layer a number
            num_nodes = num_nodes_hidden[layer] 
        
        # initialize weights and bias for each node
        network[layer_name] = {}
        for node in range(num_nodes):
            node_name = 'node_{}'.format(node+1)
            network[layer_name][node_name] = {
                'weights': np.around(np.random.uniform(size=num_nodes_previous), decimals=2),
                'bias': np.around(np.random.uniform(size=1), decimals=2),
            }
    
        num_nodes_previous = num_nodes

    return network # return the network

# %% [markdown]
# #### Utilice la función *initialize_network* para crear una red que:
#
# 1. Reciba 5 entradas.
# 2. Tenga tres capas ocultas.
# 3. Tenga 3 nodos en la primera capa, 2 nodos en la segunda capa y 3 nodos en la tercera capa.
#
# 4. Tenga 1 nodo en la capa de salida.
#
# Llame a la red **small_network**.

# %%
### type your answer here
small_network = initialize_network(5, 3, [3, 2, 3], 1)

# %% [markdown]
# ## Calcular la suma ponderada en cada nodo

# %% [markdown]
# La suma ponderada en cada nodo se calcula como el producto escalar de las entradas y los pesos más el sesgo. Así que creemos una función llamada *compute_weighted_sum* que haga precisamente eso.

# %%
def compute_weighted_sum(inputs, weights, bias):
    return np.sum(inputs * weights) + bias

# %% [markdown]
# Generemos 5 entradas que podamos alimentar a **small_network**.

# %%
from random import seed
import numpy as np

np.random.seed(12)
inputs = np.around(np.random.uniform(size=5), decimals=2)

print('The inputs to the network are {}'.format(inputs))
# Out:
# The inputs to the network are [0.15 0.74 0.26 0.53 0.01]

# %% [markdown]
# #### Utilice la función *compute_weighted_sum* para calcular la suma ponderada en el primer nodo de la primera capa oculta.

# %%
### type your answer here
node_weights = small_network['layer_1']['node_1']['weights']
node_bias = small_network['layer_1']['node_1']['bias']

weighted_sum = compute_weighted_sum(inputs, node_weights, node_bias)
print('The weighted sum at the first node in the hidden layer is {}'.format(np.around(weighted_sum[0], decimals=4)))
# Out:
# The weighted sum at the first node in the hidden layer is 1.0099

# %% [markdown]
# ## Activación del nodo de cómputo

# %% [markdown]
# Recordemos que la salida de cada nodo es simplemente una transformación no lineal de la suma ponderada. Para esta transformación, utilizamos funciones de activación. Usemos la función sigmoide como función de activación. Definamos entonces una función que recibe una suma ponderada como entrada y devuelve la transformación no lineal de dicha entrada mediante la función sigmoide.

# %%
def node_activation(weighted_sum):
    return 1.0 / (1.0 + np.exp(-1 * weighted_sum))

# %% [markdown]
# #### Utilice la función *node_activation* para calcular la salida del primer nodo en la primera capa oculta.

# %%
### type your answer here

node_output  = node_activation(compute_weighted_sum(inputs, node_weights, node_bias))
print('The output of the first node in the hidden layer is {}'.format(np.around(node_output[0], decimals=4)))
# Out:
# The output of the first node in the hidden layer is 0.733

# %% [markdown]
# ## Propagación hacia adelante

# %% [markdown]
# El último paso para construir una red neuronal capaz de realizar predicciones consiste en integrar todos los componentes. Para ello, crearemos una función que aplique las funciones *compute_weighted_sum* y *node_activation* a cada nodo de la red, propague los datos hasta la capa de salida y genere una predicción para cada nodo en dicha capa.

# %% [markdown]
# Para lograr esto, seguiremos el siguiente procedimiento:
#
# 1. Comenzaremos con la capa de entrada como entrada a la primera capa oculta.
#
# 2. Calcularemos la suma ponderada en los nodos de la capa actual.
#
# 3. Calcularemos la salida de los nodos de la capa actual.
#
# 4. Configuraremos la salida de la capa actual como entrada a la siguiente capa.
#
# 5. Pasaremos a la siguiente capa de la red.
#
# 6. Repetiremos los pasos 2 a 5 hasta calcular la salida de la capa de salida.

# %%
def forward_propagate(network, inputs):
    
    layer_inputs = list(inputs) # start with the input layer as the input to the first hidden layer
    
    for layer in network:
        
        layer_data = network[layer]
        
        layer_outputs = [] 
        for layer_node in layer_data:
        
            node_data = layer_data[layer_node]
        
            # compute the weighted sum and the output of each node at the same time 
            node_output = node_activation(compute_weighted_sum(layer_inputs, node_data['weights'], node_data['bias']))
            layer_outputs.append(np.around(node_output[0], decimals=4))
            
        if layer != 'output':
            print('The outputs of the nodes in hidden layer number {} is {}'.format(layer.split('_')[1], layer_outputs))
    
        layer_inputs = layer_outputs # set the output of this layer to be the input to next layer

    network_predictions = layer_outputs
    return network_predictions

# %% [markdown]
# #### Utilice la función *forward_propagate* para calcular la predicción de nuestra pequeña red

# %%
### type your answser here
predictions = forward_propagate(small_network, inputs)
print('The predicted value by the network for the given input is {}'.format(np.around(predictions[0], decimals=4)))
# Out:
# The outputs of the nodes in hidden layer number 1 is [0.733, 0.7505, 0.8076]
# The outputs of the nodes in hidden layer number 2 is [0.7755, 0.7987]
# The outputs of the nodes in hidden layer number 3 is [0.8888, 0.8513, 0.8168]
# The predicted value by the network for the given input is 0.8842

# %% [markdown]
# Así pues, creamos el código para definir una red neuronal. Podemos especificar el número de entradas que puede recibir una red neuronal, el número de capas ocultas, así como el número de nodos en cada capa oculta y el número de nodos en la capa de salida.

# %% [markdown]
# Primero utilizamos *initialize_network* para crear nuestra red neuronal y definir sus pesos y sesgos.

# %%
my_network = initialize_network(5, 3, [2, 3, 2], 3)

# %% [markdown]
# Entonces, para una entrada dada,

# %%
inputs = np.around(np.random.uniform(size=5), decimals=2)

# %% [markdown]
# Nosotros calculamos las predicciones de la red.

# %%
predictions = forward_propagate(my_network, inputs)
print('The predicted values by the network for the given input are {}'.format(predictions))
# Out:
# The outputs of the nodes in hidden layer number 1 is [0.8323, 0.8268]
# The outputs of the nodes in hidden layer number 2 is [0.7693, 0.6876, 0.7362]
# The outputs of the nodes in hidden layer number 3 is [0.8663, 0.8796]
# The predicted values by the network for the given input are [0.895, 0.822, 0.8032]

# %% [markdown]
# Puedes experimentar con el código creando diferentes redes con distintas estructuras y disfrutar haciendo predicciones utilizando la función *forward_propagate*.

# %% [markdown]
# ## 💻 Código de Propagación hacia Adelante
#
# A continuación se muestra el código para completar las secciones pendientes, incluyendo las variables y funciones que ya se han definido en el cuaderno (como `weights`, `biases`, `x_1`, `x_2`, `z_11`, `a_11`, `n`, `num_hidden_layers`, `m`, `num_nodes_output`, `initialize_network`, `inputs`, `node_weights`, `node_bias`, `compute_weighted_sum`, `node_activation`, y `forward_propagate`).
#
# ### 1\. Calcular la suma ponderada ($z_{1, 2}$) en el segundo nodo de la capa oculta (Celda 7)
#
# ```python
# ### type your answer here
# z_12 = x_1 * weights[2] + x_2 * weights[3] + biases[1]
# # z_12 = (input_x1 * weight_3) + (input_x2 * weight_4) + bias_2
# # weights[2] y weights[3] son los pesos que conectan la entrada con el segundo nodo de la capa oculta.
# # biases[1] es el sesgo del segundo nodo de la capa oculta.
# ```
#
# ### 2\. Calcular la activación ($a_{1, 2}$) del segundo nodo de la capa oculta (Celda 11)
#
# ```python
# ### type your answer here
# a_12 = 1.0 / (1.0 + np.exp(-z_12))
# # Se aplica la función de activación sigmoide: a = 1 / (1 + e^(-z)).
# # z_12 es la suma ponderada calculada en el paso anterior para el segundo nodo.
# ```
#
# ### 3\. Calcular la suma ponderada ($z_2$) en el nodo de la capa de salida (Celda 13)
#
# ```python
# ### type your answer here
#
# z_2 = a_11 * weights[4] + a_12 * weights[5] + biases[2]
# # z_2 = (activacion_nodo_1 * weight_5) + (activacion_nodo_2 * weight_6) + bias_3
# # a_11 y a_12 son las activaciones (salidas) de los nodos de la capa oculta anterior.
# # weights[4] y weights[5] son los pesos que conectan la capa oculta con el nodo de salida.
# # biases[2] es el sesgo del nodo de salida.
# ```
#
# ### 4\. Calcular la salida ($a_2$) de la red (activación del nodo de salida) (Celda 15)
#
# ```python
# ### type your answer here
#
# a_2 = 1.0 / (1.0 + np.exp(-z_2))
# # Se aplica la función de activación sigmoide al resultado de la suma ponderada de la capa de salida (z_2).
# # Esta activación a_2 es la predicción final de la red.
# ```
#
# ### 5\. Crear la *small\_network* (Celda 24)
#
# ```python
# ### type your answer here
# small_network = initialize_network(5, 3, [3, 2, 3], 1)
# # 5: número de entradas (num_inputs).
# # 3: número de capas ocultas (num_hidden_layers).
# # [3, 2, 3]: número de nodos en cada capa oculta (num_nodes_hidden).
# # 1: número de nodos en la capa de salida (num_nodes_output).
# ```
#
# ### 6\. Calcular la suma ponderada para el primer nodo de la primera capa oculta de la *small\_network* (Celda 27)
#
# Esta celda ya estaba mayormente resuelta en el cuaderno, pero aquí está el código para completarla (asumiendo que los valores de `inputs`, `node_weights`, `node_bias` se obtuvieron de las celdas anteriores):
#
# ```python
# ### type your answer here
# node_weights = small_network['layer_1']['node_1']['weights']
# node_bias = small_network['layer_1']['node_1']['bias']
#
# weighted_sum = compute_weighted_sum(inputs, node_weights, node_bias)
# # Se usa la función compute_weighted_sum: np.sum(inputs * weights) + bias
# print('The weighted sum at the first node in the hidden layer is {}'.format(np.around(weighted_sum[0], decimals=4)))
# ```
#
# ### 7\. Calcular la activación/salida para el primer nodo de la primera capa oculta de la *small\_network* (Celda 30)
#
# Esta celda ya estaba mayormente resuelta en el cuaderno, utilizando el resultado de la suma ponderada del paso anterior:
#
# ```python
# ### type your answer here
#
# node_output  = node_activation(compute_weighted_sum(inputs, node_weights, node_bias))
# # Se utiliza la función node_activation (sigmoide) en la suma ponderada.
# print('The output of the first node in the hidden layer is {}'.format(np.around(node_output[0], decimals=4)))
# ```
#
# ### 8\. Utilizar la función *forward\_propagate* para calcular la predicción de la *small\_network* (Celda 33)
#
# ```python
# ### type your answser here
# predictions = forward_propagate(small_network, inputs)
# # Se utiliza la función forward_propagate para alimentar las 'inputs' a través de toda la 'small_network'.
# # La función realiza el cálculo de la suma ponderada y la activación en cada capa.
# print('The predicted value by the network for the given input is {}'.format(np.around(predictions[0], decimals=4)))
# ```
#
# -----
#
# ## 🚀 Próximos pasos (Experimentación)
#
# El cuaderno finaliza con celdas vacías para la experimentación. Puedes usar el siguiente código para crear y probar diferentes redes, tal como se sugiere:
#
# ```python
# ### create a network
# new_network = initialize_network(num_inputs=4, num_hidden_layers=2, num_nodes_hidden=[4, 3], num_nodes_output=2)
# # Se crea una red con 4 entradas, 2 capas ocultas (4 y 3 nodos) y 2 nodos de salida.
#
# new_inputs = np.around(np.random.uniform(size=4), decimals=2)
# # Se generan 4 entradas aleatorias.
#
# print("--- Nueva Red (new_network) ---")
# print("Entradas:", new_inputs)
#
# new_predictions = forward_propagate(new_network, new_inputs)
# print('The predicted values by the network for the given input are {}'.format(new_predictions))
# ```
#
# ¿Te gustaría que te ayudara a **ejecutar o verificar alguna de las secciones completadas** en el contexto de tu entorno de trabajo, o quizás **explicar con más detalle** la función `forward_propagate`?
